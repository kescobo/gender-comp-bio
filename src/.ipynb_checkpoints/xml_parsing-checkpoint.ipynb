# %% [markdown]
# # Parsing Pubmed XML file
#
# Data sets can be found [here](https://github.com/kescobo/gender-comp-bio/tree/master/data).
#
# ## Goals
#
# Raw data from pubmed is contained in xml files, and we'd like to extract author and date information into a spreadsheet for easier analysis.
#
# The first thing to do is to make sure to set the working directory to where the data is.

# %%
import os

print(os.getcwd())
# Out:
# /Users/KBLaptop/computation/gender-comp-bio/src

# %%
os.chdir("../data/")
os.listdir()
# Out:
# ['.DS_Store',
#  'all_bio_pubs.csv',
#  'author_list.csv',
#  'biology-1997-2014.xml',
#  'comp-bio-1997-2014.xml',
#  'compbio_pubs.csv',
#  'compbio_pubs2.csv',
#  'github_pubs.csv',
#  'github_pubs.xml',
#  'README.md',
#  'test_1.xml',
#  'test_2.xml',
#  'test_3.xml']

# %% [markdown]
# Next, we'll need to parse the xml files. We can do this using the built-in [python xml module](https://docs.python.org/3.5/library/xml.etree.elementtree.html).

# %%
import xml.etree.ElementTree as ET
import datetime

xml_handle = ET.parse('github_pubs.xml')
root = xml_handle.getroot()

for citation in root.iter("MedlineCitation"):
    pmid = citation[0].text
    pubdate = datetime.date(
        int(citation[1][0].text),  # year
        int(citation[1][1].text),  # month
        int(citation[1][2].text)  # day
        )
    
    Journal = next(citation.iter("Journal"))

    journal_title = Journal.find("ISOAbbreviation").text
    
    abstract = next(citation.iter("AbstractText")).text
    
    # some articles don't have author fields - ignoring those
    try:
        authors = [{
                "Last": author.find("LastName").text,
                "First": author.find("ForeName").text
                   } for author in Citation.iter("Author")]
    except:
        continue
    
    print("PMID: {}\nJournal: {}\nAuthors: {}\n".format(
        pmid, journal_title, [(x['Last'], x['First']) for x in authors]))

# %% [markdown]
# ### Class Definition
#
# Just because I need the practice, I'm going to set up an `Article` class to hold the data and make working with it easier, and an `Author` class that we can use to deal with author names

# %%
class Article(object):
    """Container for publication info"""
    def __init__(self, pmid, pubdate, journal, title, abstract, authors):
        self.pmid = pmid
        self.pubdate = pubdate
        self.journal = journal
        self.title = title
        self.abstract = abstract
        self.authors = authors
    def __repr__(self):
        return "<Article PMID: {}>".format(self.pmid)

    def get_authors(self):
        for author in self.authors:
            yield author

class Author(object):
    def __init__(self, last_name, first_name):
        assert type(last_name) == str
        assert type(first_name) == str
        
        self.last_name = last_name
        self.first_name = first_name.split()[0]
        try:
            self.initials = " ".join(first_name.split()[1:])
        except IndexError:
            self.initials = None

# %% [markdown]
# ### Generator Function
#
# And... we can turn the code above into a generator function that yields an `Article` for each document

# %%
from lxml.etree import iterparse

def iter_parse_pubmed(xml_file):
    # get an iterable
    context = iterparse(xml_file, events=('end',), tag='PubmedArticle')
    counter = 0
    for event, elem in context:
        counter += 1
        print(elem.tag)
        if counter > 5:
            return

# %%
iter_parse_pubmed('github_pubs.xml')
# Out:
# PubmedArticle
# PubmedArticle
# PubmedArticle
# PubmedArticle
# PubmedArticle
# PubmedArticle

# %%
def parse_pubmed_xml(xml_file):
    xml_handle = ET.parse(xml_file)
    root = xml_handle.getroot()

    for citation in root.iter("MedlineCitation"):
        pmid = citation[0].text
        pubdate = datetime.date(
            int(citation[1][0].text),  # year
            int(citation[1][1].text),  # month
            int(citation[1][2].text)  # day
            )
        
        journal = next(citation.iter("Journal"))

        j_title = journal.find("ISOAbbreviation")
        if j_title:
            journal_title = j_title.text
        else:
            journal_title = None
            
        try:
            article_title = next(citation.iter("ArticleTitle")).text
        except:
            article_title = None
        
        try:
            abstract = next(citation.iter("AbstractText")).text
        except:
            abstract = None
        try:
            authors = [Author(author.find("LastName").text, author.find("ForeName").text)
                for author in citation.iter("Author")]
        except:
            continue
        
        yield Article(pmid, pubdate, journal_title, article_title, abstract, authors)

# %% [markdown]
# Usage:

# %%
for article in parse_pubmed_xml('github_pubs.xml'):
    print(article)
    print(article.pubdate)
    for author in article.get_authors():
        print("{}, {} {}".format(author.last_name, author.first_name, author.initials))
    print()
# Out:
# <Article PMID: 26357045>
# 2015-09-11
# Shiraishi, Fumihide
# Yoshida, Erika
# Voit, Eberhard O
#
# <Article PMID: 25601296>
# 2015-01-20
# Dixit, Abhishek
# Dobson, Richard J B
#
# <Article PMID: 25558360>
# 2015-01-05
# Tuck, Sean L
# Phillips, Helen Rp
# Hintzen, Rogier E
# Scharlemann, Jörn Pw
# Purvis, Andy
# Hudson, Lawrence N
#
# <Article PMID: 25553811>
# 2015-01-02
# Chen, Junfang
# Lutsik, Pavlo
# Akulenko, Ruslan
# Walter, Jörn
# Helms, Volkhard
#
# <Article PMID: 25549775>
# 2015-06-09
# Manini, Simone
# Antiga, Luca
# Botti, Lorenzo
# Remuzzi, Andrea
#
# <Article PMID: 25543048>
# 2015-04-28
# Bouvier, Guillaume
# Desdouits, Nathan
# Ferber, Mathias
# Blondel, Arnaud
# Nilges, Michael
#
# <Article PMID: 25540185>
# 2015-04-28
# Meinicke, Peter
#
# <Article PMID: 25527832>
# 2015-04-12
# Lindberg, Michael R
# Hall, Ira M
# Quinlan, Aaron R
#
# <Article PMID: 25526884>
# 2015-04-27
# Barton, Carl
# Heliou, Alice
# Mouchard, Laurent
# Pissis, Solon P
#
# <Article PMID: 25524895>
# 2015-04-28
# Mu, John C
# Mohiyuddin, Marghoob
# Li, Jian
# Bani Asadi, Narges
# Gerstein, Mark B
# Abyzov, Alexej
# Wong, Wing H
# Lam, Hugo Y K
#
# <Article PMID: 25521965>
# 2014-12-19
# Wu, Chengkun
# Schwartz, Jean-Marc
# Brabant, Georg
# Nenadic, Goran
#
# <Article PMID: 25520192>
# 2015-01-24
# Gardner, Paul P
# Eldai, Hisham
#
# <Article PMID: 25514851>
# 2015-02-06
# Anvar, Seyed Yahya
# Khachatryan, Lusine
# Vermaat, Martijn
# van Galen, Michiel
# Pulyakhina, Irina
# Ariyurek, Yavuz
# Kraaijeveld, Ken
# den Dunnen, Johan T
# de Knijff, Peter
# 't Hoen, Peter A C
# Laros, Jeroen F J
#
# <Article PMID: 25505094>
# 2015-04-12
# Bliven, Spencer E
# Bourne, Philip E
# Prlić, Andreas
#
# <Article PMID: 25505087>
# 2015-04-12
# Völkel, Gunnar
# Lausser, Ludwig
# Schmid, Florian
# Kraus, Johann M
# Kestler, Hans A
#
# <Article PMID: 25505086>
# 2015-04-12
# Navarro-Gomez, Daniel
# Leipzig, Jeremy
# Shen, Lishuang
# Lott, Marie
# Stassen, Alphons P M
# Wallace, Douglas C
# Wiggs, Janey L
# Falk, Marni J
# van Oven, Mannis
# Gai, Xiaowu
#
# <Article PMID: 25504847>
# 2015-04-12
# Haubold, Bernhard
# Klötzl, Fabian
# Pfaffelhuber, Peter
#
# <Article PMID: 25481009>
# 2015-04-12
# Hussan, Jagir R
# Hunter, Peter J
# Gladding, Patrick A
# Greenberg, Neil
# Christie, Richard
# Wu, Alan
# Sorby, Hugh
# Thomas, James D
#
# <Article PMID: 25481007>
# 2015-04-12
# Wintersinger, Jeff A
# Wasmuth, James D
#
# <Article PMID: 25480375>
# 2015-04-12
# Harvey, Chris T
# Moyerbrailean, Gregory A
# Davis, Gordon O
# Wen, Xiaoquan
# Luca, Francesca
# Pique-Regi, Roger
#
# <Article PMID: 25474353>
# 2014-12-05
# Gavryushkina, Alexandra
# Welch, David
# Stadler, Tanja
# Drummond, Alexei J
#
# <Article PMID: 25461763>
# 2014-12-03
# Zhu, Xiao
# Leung, Henry C M
# Chin, Francis Y L
# Yiu, Siu Ming
# Quan, Guangri
# Liu, Bo
# Wang, Yadong
#
# <Article PMID: 25452688>
# 2014-12-02
# Lee, Wan-Ping
# Wu, Jiantao
# Marth, Gabor T
#
# <Article PMID: 25435543>
# 2015-01-31
# Sheng, Quanhu
# Li, Rongxia
# Dai, Jie
# Li, Qingrun
# Su, Zhiduan
# Guo, Yan
# Li, Chen
# Shyr, Yu
# Zeng, Rong
#
# <Article PMID: 25431162>
# 2015-04-27
# Warnecke, Andreas
# Sandalova, Tatyana
# Achour, Adnane
# Harris, Robert A
#
# <Article PMID: 25428347>
# 2015-02-18
# Diaz, Aaron A
# Qin, Han
# Ramalho-Santos, Miguel
# Song, Jun S
#
# <Article PMID: 25422674>
# 2014-11-25
# Inouye, Michael
# Dashnow, Harriet
# Raven, Lesley-Ann
# Schultz, Mark B
# Pope, Bernard J
# Tomita, Takehiro
# Zobel, Justin
# Holt, Kathryn E
#
# <Article PMID: 25414364>
# 2015-04-03
# Hirsh, Layla
# Piovesan, Damiano
# Giollo, Manuel
# Ferrari, Carlo
# Tosatto, Silvio C E
#
# <Article PMID: 25414349>
# 2015-02-18
# Croucher, Nicholas J
# Page, Andrew J
# Connor, Thomas R
# Delaney, Aidan J
# Keane, Jacqueline A
# Bentley, Stephen D
# Parkhill, Julian
# Harris, Simon R
#
# <Article PMID: 25410596>
# 2015-01-07
# Treangen, Todd J
# Ondov, Brian D
# Koren, Sergey
# Phillippy, Adam M
#
# <Article PMID: 25408304>
# 2015-02-24
# Clarkson, Matthew J
# Zombori, Gergely
# Thompson, Steve
# Totz, Johannes
# Song, Yi
# Espak, Miklos
# Johnsen, Stian
# Hawkes, David
# Ourselin, Sébastien
#
# <Article PMID: 25407910>
# 2015-04-27
# McCorrison, Jamison M
# Venepally, Pratap
# Singh, Indresh
# Fouts, Derrick E
# Lasken, Roger S
# Methé, Barbara A
#
# <Article PMID: 25406361>
# 2014-12-17
# Shenker, Sol
# Miura, Pedro
# Sanfilippo, Piero
# Lai, Eric C
#
# <Article PMID: 25402475>
# 2014-11-18
# Vaksman, Zalman
# Fonville, Natalie C
# Tae, Hongseok
# Garner, Harold R
#
# <Article PMID: 25399553>
# 2014-12-16
# Sang, Xiahan
# Oni, Adedapo A
# LeBeau, James M
#
# <Article PMID: 25393678>
# 2014-11-14
# Chung, Dongjun
# Yang, Can
# Li, Cong
# Gelernter, Joel
# Zhao, Hongyu
#
# <Article PMID: 25375164>
# 2014-11-07
# Zhang, Qing
# Yu, Hong
#
# <Article PMID: 25372389>
# 2014-11-06
# Nelissen, Bastiaan G L
# van Herwaarden, Joost A
# Moll, Frans L
# van Diest, Paul J
# Pasterkamp, Gerard
#
# <Article PMID: 25372312>
# 2014-12-16
# Nategholeslam, Mostafa
# Gray, C G
# Tomberli, Bruno
#
# <Article PMID: 25371478>
# 2015-02-27
# Smith, Rob
# Prince, John T
#
# <Article PMID: 25367074>
# 2015-03-31
# Maretty, Lasse
# Sibbesen, Jonas Andreas
# Krogh, Anders
#
# <Article PMID: 25361575>
# 2015-01-23
# Pang, Chao
# Hendriksen, Dennis
# Dijkstra, Martijn
# van der Velde, K Joeri
# Kuiper, Joel
# Hillege, Hans L
# Swertz, Morris A
#
# <Article PMID: 25359887>
# 2015-02-27
# Taylor, Ryan
# Miller, Ryan H
# Miller, Ryan D
# Porter, Michael
# Dalgleish, James
# Prince, John T
#
# <Article PMID: 25356683>
# 2014-10-31
# Fang, Hai
#
# <Article PMID: 25352981>
# 2014-10-31
# Chakraborty, Sandeep
# Rao, Basuthkar
# Dandekar, Abhaya
#
# <Article PMID: 25352552>
# 2015-01-16
# Cunningham, Fiona
# Amode, M Ridwan
# Barrell, Daniel
# Beal, Kathryn
# Billis, Konstantinos
# Brent, Simon
# Carvalho-Silva, Denise
# Clapham, Peter
# Coates, Guy
# Fitzgerald, Stephen
# Gil, Laurent
# Girón, Carlos García
# Gordon, Leo
# Hourlier, Thibaut
# Hunt, Sarah E
# Janacek, Sophie H
# Johnson, Nathan
# Juettemann, Thomas
# Kähäri, Andreas K
# Keenan, Stephen
# Martin, Fergal J
# Maurel, Thomas
# McLaren, William
# Murphy, Daniel N
# Nag, Rishi
# Overduin, Bert
# Parker, Anne
# Patricio, Mateus
# Perry, Emily
# Pignatelli, Miguel
# Riat, Harpreet Singh
# Sheppard, Daniel
# Taylor, Kieron
# Thormann, Anja
# Vullo, Alessandro
# Wilder, Steven P
# Zadissa, Amonida
# Aken, Bronwen L
# Birney, Ewan
# Harrow, Jennifer
# Kinsella, Rhoda
# Muffato, Matthieu
# Ruffier, Magali
# Searle, Stephen M J
# Spudich, Giulietta
# Trevanion, Stephen J
# Yates, Andy
# Zerbino, Daniel R
# Flicek, Paul
#
# <Article PMID: 25350584>
# 2014-10-29
# Weirick, Tyler
# Sahu, Sitanshu S
# Mahalingam, Ramamurthy
# Kaundal, Rakesh
#
# <Article PMID: 25348215>
# 2015-02-27
# Edmands, William M B
# Barupal, Dinesh K
# Scalbert, Augustin
#
# <Article PMID: 25348214>
# 2015-02-27
# Kruger, Felix A
# Gaulton, Anna
# Nowotka, Michal
# Overington, John P
#
# <Article PMID: 25344498>
# 2015-02-27
# Younsi, Reda
# MacLean, Dan
#
# <Article PMID: 25344497>
# 2015-02-27
# Lekschas, Fritz
# Stachelscheid, Harald
# Seltmann, Stefanie
# Kurtz, Andreas
#
# <Article PMID: 25344330>
# 2015-03-31
# Menor, Mark
# Ching, Travers
# Zhu, Xun
# Garmire, David
# Garmire, Lana X
#
# <Article PMID: 25343723>
# 2014-10-25
# Beas-Luna, Rodrigo
# Novak, Mark
# Carr, Mark H
# Tinker, Martin T
# Black, August
# Caselle, Jennifer E
# Hoban, Michael
# Malone, Dan
# Iles, Alison
#
# <Article PMID: 25342065>
# 2015-02-13
# Han, Bo W
# Wang, Wei
# Zamore, Phillip D
# Weng, Zhiping
#
# <Article PMID: 25338721>
# 2015-02-27
# Gula, Igor A
# Samsonov, Alexander M
#
# <Article PMID: 25338717>
# 2015-02-27
# Hoogstrate, Youri
# Jenster, Guido
# Martens-Uzunova, Elena S
#
# <Article PMID: 25336502>
# 2015-02-13
# Willet, Cali E
# Haase, Bianca
# Charleston, Michael A
# Wade, Claire M
#
# <Article PMID: 25332377>
# 2015-02-13
# Beck, Daniel
# Dennis, Christopher
# Foster, James A
#
# <Article PMID: 25330359>
# 2014-10-21
# Abby, Sophie S
# Néron, Bertrand
# Ménager, Hervé
# Touchon, Marie
# Rocha, Eduardo P C
#
# <Article PMID: 25324962>
# 2014-10-20
# Saravia, Leonardo A
#
# <Article PMID: 25322836>
# 2015-01-29
# Schmid, Marc W
# Grossniklaus, Ueli
#
# <Article PMID: 25322835>
# 2015-02-13
# Jang, Insu
# Chang, Hyeshik
# Jun, Yukyung
# Park, Seongjin
# Yang, Jin Ok
# Lee, Byungwook
# Kim, Wankyu
# Kim, V Narry
# Lee, Sanghyuk
#
# <Article PMID: 25322818>
# 2014-10-24
# Guo, Yan
# Zhao, Shilin
# Lehmann, Brian D
# Sheng, Quanhu
# Shaver, Timothy M
# Stricker, Thomas P
# Pietenpol, Jennifer A
# Shyr, Yu
#
# <Article PMID: 25319962>
# 2015-01-29
# Taylor, Avigail
# Steinberg, Julia
# Andrews, Tallulah S
# Webber, Caleb
#
# <Article PMID: 25294822>
# 2014-11-28
# Leek, Jeffrey T
#
# <Article PMID: 25285208>
# 2014-10-08
# Fortin, Jean-Philippe
# Fertig, Elana
# Hansen, Kasper
#
# <Article PMID: 25281234>
# 2014-10-04
# Ameur, Adam
# Bunikis, Ignas
# Enroth, Stefan
# Gyllensten, Ulf
#
# <Article PMID: 25276335>
# 2014-10-03
# Hettne, Kristina M
# Dharuri, Harish
# Zhao, Jun
# Wolstencroft, Katherine
# Belhajjame, Khalid
# Soiland-Reyes, Stian
# Mina, Eleni
# Thompson, Mark
# Cruickshank, Don
# Verdes-Montenegro, Lourdes
# Garrido, Julian
# de Roure, David
# Corcho, Oscar
# Klyne, Graham
# van Schouwen, Reinout
# 't Hoen, Peter A C
# Bechhofer, Sean
# Goble, Carole
# Roos, Marco
#
# <Article PMID: 25273112>
# 2015-01-29
# Chaudhary, Ruchi
# Fernández-Baca, David
# Burleigh, John Gordon
#
# <Article PMID: 25270638>
# 2015-01-10
# Trubetskoy, Vassily
# Rodriguez, Alex
# Dave, Uptal
# Campbell, Nicholas
# Crawford, Emily L
# Cook, Edwin H
# Sutcliffe, James S
# Foster, Ian
# Madduri, Ravi
# Cox, Nancy J
# Davis, Lea K
#
# <Article PMID: 25262154>
# 2015-01-10
# McMurdie, Paul J
# Holmes, Susan
#
# <Article PMID: 25254639>
# 2014-09-26
# Hepler, N Lance
# Scheffler, Konrad
# Weaver, Steven
# Murrell, Ben
# Richman, Douglas D
# Burton, Dennis R
# Poignard, Pascal
# Smith, Davey M
# Kosakovsky Pond, Sergei L
#
# <Article PMID: 25253358>
# 2014-09-25
# Beckmann, Noam D
# Karri, Sashank
# Fang, Gang
# Bashir, Ali
#
# <Article PMID: 25252881>
# 2014-09-25
# Gholami, Milad
# Arbabi, Aryan
# Sharifi-Zarchi, Ali
# Chitsaz, Hamidreza
# Sadeghi, Mehdi
#
# <Article PMID: 25236461>
# 2014-12-20
# Yates, Andrew
# Beal, Kathryn
# Keenan, Stephen
# McLaren, William
# Pignatelli, Miguel
# Ritchie, Graham R S
# Ruffier, Magali
# Taylor, Kieron
# Vullo, Alessandro
# Flicek, Paul
#
# <Article PMID: 25232314>
# 2014-09-18
# Stefanini, Fabio
# Neftci, Emre O
# Sheik, Sadique
# Indiveri, Giacomo
#
# <Article PMID: 25231498>
# 2014-09-18
# Karr, Jonathan R
# Phillips, Nolan C
# Covert, Markus W
#
# <Article PMID: 25212755>
# 2014-12-20
# Morris, John H
# Wu, Allan
# Yamashita, Roxanne A
# Marchler-Bauer, Aron
# Ferrin, Thomas E
#
# <Article PMID: 25206364>
# 2014-09-10
# Cadzow, Murray
# Boocock, James
# Nguyen, Hoang T
# Wilcox, Phillip
# Merriman, Tony R
# Black, Michael A
#
# <Article PMID: 25202595>
# 2014-09-09
# Salinas, Nelson R
# Little, Damon P
#
# <Article PMID: 25192740>
# 2014-12-20
# Chiba, Kenichi
# Shiraishi, Yuichi
# Nagata, Yasunobu
# Yoshida, Kenichi
# Imoto, Seiya
# Ogawa, Seishi
# Miyano, Satoru
#
# <Article PMID: 25192739>
# 2014-12-20
# Lindenbaum, Pierre
# Redon, Richard
#
# <Article PMID: 25189781>
# 2014-11-26
# Robinson, David G
# Storey, John D
#
# <Article PMID: 25189778>
# 2014-12-20
# Cingolani, Pablo
# Sladek, Rob
# Blanchette, Mathieu
#
# <Article PMID: 25183856>
# 2014-09-03
# Zhu, Dongqing
# Li, Dingcheng
# Carterette, Ben
# Liu, Hongfang
#
# <Article PMID: 25183485>
# 2014-12-20
# Pomyen, Yotsawat
# Segura, Marcelo
# Ebbels, Timothy M D
# Keun, Hector C
#
# <Article PMID: 25181531>
# 2014-09-03
# Samur, Mehmet Kemal
#
# <Article PMID: 25178461>
# 2014-12-20
# Lajugie, Julien
# Fourel, Nicolas
# Bouhassira, Eric E
#
# <Article PMID: 25177538>
# 2014-09-01
# Rideout, Jai Ram
# He, Yan
# Navas-Molina, Jose A
# Walters, William A
# Ursell, Luke K
# Gibbons, Sean M
# Chase, John
# McDonald, Daniel
# Gonzalez, Antonio
# Robbins-Pianka, Adam
# Clemente, Jose C
# Gilbert, Jack A
# Huse, Susan M
# Zhou, Hong-Wei
# Knight, Rob
# Caporaso, J Gregory
#
# <Article PMID: 25170024>
# 2014-11-26
# Burren, Oliver S
# Guo, Hui
# Wallace, Chris
#
# <Article PMID: 25165093>
# 2014-11-26
# Voight, Benjamin F
#
# <Article PMID: 25161247>
# 2014-08-27
# Gönen, Mehmet
# Margolin, Adam A
#
# <Article PMID: 25161245>
# 2014-08-27
# Mirarab, S
# Reaz, R
# Bayzid, Md S
# Zimmermann, T
# Swenson, M S
# Warnow, T
#
# <Article PMID: 25161244>
# 2014-08-27
# Benner, Philipp
# Bačák, Miroslav
# Bourguignon, Pierre-Yves
#
# <Article PMID: 25161237>
# 2014-08-27
# Michel, Mirco
# Hayat, Sikander
# Skwark, Marcin J
# Sander, Chris
# Marks, Debora S
# Elofsson, Arne
#
# <Article PMID: 25161223>
# 2014-08-27
# Kuleshov, Volodymyr
#
# <Article PMID: 25160522>
# 2014-12-04
# Qiao, Yi
# Quinlan, Aaron R
# Jazaeri, Amir A
# Verhaak, Roeland Gw
# Wheeler, David A
# Marth, Gabor T
#
# <Article PMID: 25159222>
# 2014-09-02
# Zhu, Qiyun
# Kosoy, Michael
# Dittmar, Katharina
#
# <Article PMID: 25147360>
# 2014-11-26
# Mukhyala, Kiran
# Masselot, Alexandre
#
# <Article PMID: 25147359>
# 2014-11-26
# Gymrek, Melissa
#
# <Article PMID: 25147357>
# 2014-11-26
# Xie, Wei
# Kantarcioglu, Murat
# Bush, William S
# Crawford, Dana
# Denny, Joshua C
# Heatherly, Raymond
# Malin, Bradley A
#
# <Article PMID: 25143291>
# 2014-11-26
# Loman, Nicholas J
# Quinlan, Aaron R
#
# <Article PMID: 25143289>
# 2014-11-26
# Tárraga, Joaquín
# Arnau, Vicente
# Martínez, Héctor
# Moreno, Raul
# Cazorla, Diego
# Salavert-Torres, José
# Blanquer-Espert, Ignacio
# Dopazo, Joaquín
# Medina, Ignacio
#
# <Article PMID: 25138168>
# 2014-11-26
# Nguyen, Ngan
# Hickey, Glenn
# Raney, Brian J
# Armstrong, Joel
# Clawson, Hiram
# Zweig, Ann
# Karolchik, Donna
# Kent, William James
# Haussler, David
# Paten, Benedict
#
# <Article PMID: 25135945>
# 2014-10-27
# Wang, Minxian
# Huang, Xin
# Li, Ran
# Xu, Hongyang
# Jin, Li
# He, Yungang
#
# <Article PMID: 25129695>
# 2014-08-17
# Webb-Robertson, Bobbie-Jo M
# Matzke, Melissa M
# Datta, Susmita
# Payne, Samuel H
# Kang, Jiyun
# Bramer, Lisa M
# Nicora, Carrie D
# Shukla, Anil K
# Metz, Thomas O
# Rodland, Karin D
# Smith, Richard D
# Tardiff, Mark F
# McDermott, Jason E
# Pounds, Joel G
# Waters, Katrina M
#
# <Article PMID: 25123904>
# 2014-11-26
# Ephraim, Sean S
# Anand, Nikhil
# DeLuca, Adam P
# Taylor, Kyle R
# Kolbe, Diana L
# Simpson, Allen C
# Azaiez, Hela
# Sloan, Christina M
# Shearer, A Eliot
# Hallier, Andrea R
# Casavant, Thomas L
# Scheetz, Todd E
# Smith, Richard J H
# Braun, Terry A
#
# <Article PMID: 25123903>
# 2014-11-26
# Usuyama, Naoto
# Shiraishi, Yuichi
# Sato, Yusuke
# Kume, Haruki
# Homma, Yukio
# Ogawa, Seishi
# Miyano, Satoru
# Imoto, Seiya
#
# <Article PMID: 25115706>
# 2014-11-07
# Curran, David M
# Gilleard, John S
# Wasmuth, James D
#
# <Article PMID: 25107872>
# 2014-11-07
# Li, Heng
#
# <Article PMID: 25095880>
# 2014-11-07
# Larsson, Anders
#
# <Article PMID: 25093067>
# 2014-08-05
# Stenetorp, Pontus
# Pyysalo, Sampo
# Ananiadou, Sophia
# Tsujii, Jun'ichi
#
# <Article PMID: 25081493>
# 2014-08-01
# Vo, Nam S
# Tran, Quang
# Niraula, Nobal
# Phan, Vinhthuy
#
# <Article PMID: 25081207>
# 2014-09-27
# Diao, Liyang
# Marcais, Antoine
# Norton, Scott
# Chen, Kevin C
#
# <Article PMID: 25080132>
# 2014-08-01
# Ebbert, Mark T W
# Wadsworth, Mark E
# Boehme, Kevin L
# Hoyt, Kaitlyn L
# Sharp, Aaron R
# O'Fallon, Brendan D
# Kauwe, John S K
# Ridge, Perry G
#
# <Article PMID: 25079944>
# 2014-08-01
# Gonzalez, Gabriel
# Hannigan, Brett
# DeGrado, William F
#
# <Article PMID: 25075290>
# 2014-07-30
# Corpas, Manuel
# Jimenez, Rafael
# Carbon, Seth J
# García, Alex
# Garcia, Leyla
# Goldberg, Tatyana
# Gomez, John
# Kalderimis, Alexis
# Lewis, Suzanna E
# Mulvany, Ian
# Pawlik, Aleksandra
# Rowland, Francis
# Salazar, Gustavo
# Schreiber, Fabian
# Sillitoe, Ian
# Spooner, William H
# Thanki, Anil S
# Villaveces, José M
# Yachdav, Guy
# Hermjakob, Henning
#
# <Article PMID: 25075288>
# 2014-07-30
# Salazar, Gustavo A
# Meintjes, Ayton
# Mulder, Nicola
#
# <Article PMID: 25075287>
# 2014-07-30
# Villaveces, Jose M
# Jimenez, Rafael C
# Habermann, Bianca H
#
# <Article PMID: 25075120>
# 2014-10-18
# Mohamed, Ahmed
# Hancock, Timothy
# Nguyen, Canh Hao
# Mamitsuka, Hiroshi
#
# <Article PMID: 25075113>
# 2014-10-18
# Crabtree, Jonathan
# Agrawal, Sonia
# Mahurkar, Anup
# Myers, Garry S
# Rasko, David A
# White, Owen
#
# <Article PMID: 25066046>
# 2014-09-10
# Kramer, Andrei
# Calderhead, Ben
# Radde, Nicole
#
# <Article PMID: 25064568>
# 2014-10-18
# Porta-Pardo, Eduard
# Godzik, Adam
#
# <Article PMID: 25062443>
# 2014-07-26
# Zhang, Qingpeng
# Pell, Jason
# Canino-Koning, Rosangela
# Howe, Adina Chuang
# Brown, C Titus
#
# <Article PMID: 25056180>
# 2014-08-08
# Jaschob, Daniel
# Davis, Trisha N
# Riffle, Michael
#
# <Article PMID: 25028724>
# 2014-10-18
# Nicolazzi, Ezequiel L
# Iamartino, Daniela
# Williams, John L
#
# <Article PMID: 25005749>
# 2014-10-04
# Kramer, Andrei
# Stathopoulos, Vassilios
# Girolami, Mark
# Radde, Nicole
#
# <Article PMID: 25004097>
# 2014-07-09
# Rosenberg, Michael S
#
# <Article PMID: 25000497>
# 2014-07-08
# Kauffman, Julie
# Kittas, Aristotelis
# Bennett, Laura
# Tsoka, Sophia
#
# <Article PMID: 24994890>
# 2015-02-13
# Biehl, Michael
# Sadowski, Peter
# Bhanot, Gyan
# Bilal, Erhan
# Dayarian, Adel
# Meyer, Pablo
# Norel, Raquel
# Rhrissorrakrai, Kahn
# Zeller, Michael D
# Hormoz, Sahand
#
# <Article PMID: 24990608>
# 2014-10-04
# Patel, Hitesh
# Grüning, Björn A
# Günther, Stefan
# Merfort, Irmgard
#
# <Article PMID: 24976859>
# 2014-06-30
# Zamani, Neda
# Sundström, Görel
# Höppner, Marc P
# Grabherr, Manfred G
#
# <Article PMID: 24976580>
# 2014-07-09
# Zamani, Neda
# Sundström, Görel
# Meadows, Jennifer R S
# Höppner, Marc P
# Dainat, Jacques
# Lantz, Henrik
# Haas, Brian J
# Grabherr, Manfred G
#
# <Article PMID: 24974206>
# 2014-10-04
# Malaspinas, Anna-Sapfo
# Tange, Ole
# Moreno-Mayar, José Víctor
# Rasmussen, Morten
# DeGiorgio, Michael
# Wang, Yong
# Valdiosera, Cristina E
# Politis, Gustavo
# Willerslev, Eske
# Nielsen, Rasmus
#
# <Article PMID: 24970577>
# 2014-08-22
# Layer, Ryan M
# Chiang, Colby
# Quinlan, Aaron R
# Hall, Ira M
#
# <Article PMID: 24950811>
# 2014-09-25
# Janin, Lilian
# Schulz-Trieglaff, Ole
# Cox, Anthony J
#
# <Article PMID: 24947752>
# 2014-09-25
# Zheng, Yinan
# Fei, Zhe
# Zhang, Wei
# Starren, Justin B
# Liu, Lei
# Baccarelli, Andrea A
# Li, Yi
# Hou, Lifang
#
# <Article PMID: 24939150>
# 2014-09-25
# Kim, Yongkyu
# Liesack, Werner
#
# <Article PMID: 24932000>
# 2014-06-16
# Bao, Ergude
# Jiang, Tao
# Girke, Thomas
#
# <Article PMID: 24931998>
# 2014-06-16
# Kolmogorov, Mikhail
# Raney, Brian
# Paten, Benedict
# Pham, Son
#
# <Article PMID: 24931990>
# 2014-06-16
# Zitnik, Marinka
# Zupan, Blaž
#
# <Article PMID: 24931986>
# 2014-06-16
# Rampášek, Ladislav
# Arbabi, Aryan
# Brudno, Michael
#
# <Article PMID: 24931983>
# 2014-06-16
# Arkin, Ya'ara
# Rahmani, Elior
# Kleber, Marcus E
# Laaksonen, Reijo
# März, Winfried
# Halperin, Eran
#
# <Article PMID: 24930140>
# 2014-09-25
# Lei, Jikai
# Sun, Yanni
#
# <Article PMID: 24928211>
# 2014-09-25
# Leo, Simone
# Pireddu, Luca
# Cuccuru, Gianmauro
# Lianas, Luca
# Soranzo, Nicola
# Afgan, Enis
# Zanetti, Gianluigi
#
# <Article PMID: 24907369>
# 2014-09-25
# Mose, Lisle E
# Wilkerson, Matthew D
# Hayes, D Neil
# Perou, Charles M
# Parker, Joel S
#
# <Article PMID: 24903420>
# 2014-09-25
# Phanstiel, Douglas H
# Boyle, Alan P
# Araya, Carlos L
# Snyder, Michael P
#
# <Article PMID: 24890372>
# 2014-12-17
# Nevado, B
# Perez-Enciso, M
#
# <Article PMID: 24885165>
# 2014-06-04
# Salazar, Gustavo A
# Meintjes, Ayton
# Mazandu, Gaston K
# Rapanoël, Holifidy A
# Akinola, Richard O
# Mulder, Nicola J
#
# <Article PMID: 24879305>
# 2014-06-02
# Houbraken, Maarten
# Demeyer, Sofie
# Michoel, Tom
# Audenaert, Pieter
# Colle, Didier
# Pickavet, Mario
#
# <Article PMID: 24876377>
# 2014-09-06
# Wang, Chen
# Evans, Jared M
# Bhagwate, Aditya V
# Prodduturi, Naresh
# Sarangi, Vivekananda
# Middha, Mridu
# Sicotte, Hugues
# Vedell, Peter T
# Hart, Steven N
# Oliver, Gavin R
# Kocher, Jean-Pierre A
# Maurer, Matthew J
# Novak, Anne J
# Slager, Susan L
# Cerhan, James R
# Asmann, Yan W
#
# <Article PMID: 24872423>
# 2014-09-06
# Conley, Christopher J
# Smith, Rob
# Torgrip, Ralf J O
# Taylor, Ryan M
# Tautenhahn, Ralf
# Prince, John T
#
# <Article PMID: 24867941>
# 2014-09-06
# Boyle, Evan A
# O'Roak, Brian J
# Martin, Beth K
# Kumar, Akash
# Shendure, Jay
#
# <Article PMID: 24860644>
# 2014-05-26
# Yachdav, Guy
# Hecht, Maximilian
# Pasmanik-Chor, Metsada
# Yeheskel, Adva
# Rost, Burkhard
#
# <Article PMID: 24860160>
# 2014-09-06
# Silva, Israel T
# Rosales, Rafael A
# Holanda, Adriano J
# Nussenzweig, Michel C
# Jankovic, Mila
#
# <Article PMID: 24855438>
# 2014-05-23
# Powney, Gary D
# Brooks, Stephen J
# Barwell, Louise J
# Bowles, Phil
# Fitt, Robert N L
# Pavitt, Alyson
# Spriggs, Rebecca A
# Isaac, Nick J B
#
# <Article PMID: 24845654>
# 2014-09-06
# Quinn, Andrew
# Juneja, Punita
# Jiggins, Francis M
#
# <Article PMID: 24845653>
# 2014-08-27
# Seth, Sohan
# Välimäki, Niko
# Kaski, Samuel
# Honkela, Antti
#
# <Article PMID: 24830957>
# 2014-06-23
# Thibault, Julien C
# Cheatham, Thomas E
# Facelli, Julio C
#
# <Article PMID: 24828207>
# 2014-05-15
# Schlosberg, Arran
# Lam, Brian Y H
# Yeo, Giles S H
# Clifton-Bligh, Roderick J
#
# <Article PMID: 24825614>
# 2014-08-27
# Lancaster, Alex K
# Nutter-Upham, Andrew
# Lindquist, Susan
# King, Oliver D
#
# <Article PMID: 24812344>
# 2014-08-27
# Faust, Gregory G
# Hall, Ira M
#
# <Article PMID: 24794932>
# 2014-08-27
# Plieskatt, Jordan
# Rinaldi, Gabriel
# Brindley, Paul J
# Jia, Xinying
# Potriquet, Jeremy
# Bethony, Jeffrey
# Mulvenna, Jason
#
# <Article PMID: 24790156>
# 2014-08-06
# Goodswen, Stephen J
# Kennedy, Paul J
# Ellis, John T
#
# <Article PMID: 24753484>
# 2014-08-06
# Vaughan, Timothy G
# Kühnert, Denise
# Popinga, Alex
# Welch, David
# Drummond, Alexei J
#
# <Article PMID: 24753423>
# 2014-06-20
# Zhuang, Jiali
# Wang, Jie
# Theurkauf, William
# Weng, Zhiping
#
# <Article PMID: 24743991>
# 2014-04-18
# Liu, Tao
#
# <Article PMID: 24741440>
# 2014-04-21
# Garcia, Leyla
# Yachdav, Guy
# Martin, Maria-Jesus
#
# <Article PMID: 24733292>
# 2014-07-19
# Derkach, Andriy
# Chiang, Theodore
# Gong, Jiafen
# Addis, Laura
# Dobbins, Sara
# Tomlinson, Ian
# Houlston, Richard
# Pal, Deb K
# Strug, Lisa J
#
# <Article PMID: 24728856>
# 2014-07-19
# Cánovas, Rodrigo
# Moffat, Alistair
# Turpin, Andrew
#
# <Article PMID: 24728855>
# 2014-07-19
# Pennell, Matthew W
# Eastman, Jonathan M
# Slater, Graham J
# Brown, Joseph W
# Uyeda, Josef C
# FitzJohn, Richard G
# Alfaro, Michael E
# Harmon, Luke J
#
# <Article PMID: 24727652>
# 2014-05-30
# Knijnenburg, Theo A
# Ramsey, Stephen A
# Berman, Benjamin P
# Kennedy, Kathleen A
# Smit, Arian F A
# Wessels, Lodewyk F A
# Laird, Peter W
# Aderem, Alan
# Shmulevich, Ilya
#
# <Article PMID: 24715980>
# 2014-04-09
# Villaveces, Jose M
# Jimenez, Rafael C
# Habermann, Bianca H
#
# <Article PMID: 24707447>
# 2014-04-07
# Grant, Jessica R
# Katz, Laura A
#
# <Article PMID: 24703969>
# 2014-06-14
# Guo, Yan
# Zhao, Shilin
# Sheng, Quanhu
# Ye, Fei
# Li, Jiang
# Lehmann, Brian
# Pietenpol, Jennifer
# Samuels, David C
# Shyr, Yu
#
# <Article PMID: 24700534>
# 2014-06-12
# Moruz, Luminita
# Käll, Lukas
#
# <Article PMID: 24695491>
# 2014-04-03
# Botta, Vincent
# Louppe, Gilles
# Geurts, Pierre
# Wehenkel, Louis
#
# <Article PMID: 24695406>
# 2014-07-19
# Li, Yi
# Xie, Xiaohui
#
# <Article PMID: 24688855>
# 2014-04-01
# Christensen, Anders S
# Hamelryck, Thomas
# Jensen, Jan H
#
# <Article PMID: 24681267>
# 2014-05-06
# Myers-Turnbull, Douglas
# Bliven, Spencer E
# Rose, Peter W
# Aziz, Zaid K
# Youkharibache, Philippe
# Bourne, Philip E
# Prlić, Andreas
#
# <Article PMID: 24677618>
# 2014-04-23
# Jäger, Marten
# Wang, Kai
# Bauer, Sebastian
# Smedley, Damian
# Krawitz, Peter
# Robinson, Peter N
#
# <Article PMID: 24675810>
# 2014-03-28
# Töpfer, Armin
# Marschall, Tobias
# Bull, Rowena A
# Luciani, Fabio
# Schönhuth, Alexander
# Beerenwinkel, Niko
#
# <Article PMID: 24672471>
# 2014-03-27
# Eklund, Anders
# Dufort, Paul
# Villani, Mattias
# Laconte, Stephen
#
# <Article PMID: 24667828>
# 2014-03-26
# Burdge, David A
# Libourel, Igor G L
#
# <Article PMID: 24658388>
# 2014-04-03
# Keshtkaran, Mohammad Reza
# Yang, Zhi
#
# <Article PMID: 24657354>
# 2014-06-03
# Park, Min Tae M
# Pipitone, Jon
# Baer, Lawrence H
# Winterburn, Julie L
# Shah, Yashvi
# Chavez, Sofia
# Schira, Mark M
# Lobaugh, Nancy J
# Lerch, Jason P
# Voineskos, Aristotle N
# Chakravarty, M Mallar
#
# <Article PMID: 24653694>
# 2014-03-21
# Billinger, Martin
# Brunner, Clemens
# Müller-Putz, Gernot R
#
# <Article PMID: 24647222>
# 2014-03-20
# Greshake, Bastian
# Bayer, Philipp E
# Rausch, Helge
# Reda, Julia
#
# <Article PMID: 24627804>
# 2014-03-14
# Kalderimis, Alexis
# Stepan, Radek
# Sullivan, Julie
# Lyne, Rachel
# Lyne, Michael
# Micklem, Gos
#
# <Article PMID: 24618470>
# 2014-06-27
# Buettner, Florian
# Moignard, Victoria
# Göttgens, Berthold
# Theis, Fabian J
#
# <Article PMID: 24602450>
# 2014-03-24
# Venkatachalam, Balaji
# Gusfield, Dan
# Frid, Yelena
#
# <Article PMID: 24588150>
# 2014-03-04
# Ljubetič, Ajasja
# Urbančič, Iztok
# Štrancar, Janez
#
# <Article PMID: 24586045>
# 2014-05-26
# Yahara, Koji
# Didelot, Xavier
# Ansari, M Azim
# Sheppard, Samuel K
# Falush, Daniel
#
# <Article PMID: 24574113>
# 2014-06-16
# Lärkeryd, Adrian
# Myrtennäs, Kerstin
# Karlsson, Edvin
# Dwibedi, Chinmay Kumar
# Forsman, Mats
# Larsson, Pär
# Johansson, Anders
# Sjödin, Andreas
#
# <Article PMID: 24567544>
# 2014-06-16
# Deu-Pons, Jordi
# Schroeder, Michael P
# Lopez-Bigas, Nuria
#
# <Article PMID: 24564867>
# 2014-02-25
# Bu, Jingde
# Chi, Xuebin
# Jin, Zhong
#
# <Article PMID: 24564732>
# 2014-02-25
# González-Beltrán, Alejandra
# Neumann, Steffen
# Maguire, Eamonn
# Sansone, Susanna-Assunta
# Rocca-Serra, Philippe
#
# <Article PMID: 24564706>
# 2014-02-25
# Soueidan, Hayssam
# Maurier, Florence
# Groppi, Alexis
# Sirand-Pugnet, Pascal
# Tardy, Florence
# Citti, Christine
# Dupuy, Virginie
# Nikolski, Macha
#
# <Article PMID: 24564637>
# 2014-02-25
# Zhang, Wen
# Wan, Ying-Wooi
# Allen, Genevera I
# Pang, Kaifang
# Anderson, Matthew L
# Liu, Zhandong
#
# <Article PMID: 24564427>
# 2014-02-25
# Wong, Daniel
# Li, Xiao-Li
# Wu, Min
# Zheng, Jie
# Ng, See-Kiong
#
# <Article PMID: 24564231>
# 2014-02-25
# Zhang, Zhe
# Leipzig, Jeremy
# Sasson, Ariella
# Yu, Angela M
# Perin, Juan C
# Xie, Hongbo M
# Sarmady, Mahdi
# Warren, Patrick V
# White, Peter S
#
# <Article PMID: 24561350>
# 2014-03-21
# Moore, Hyatt E
# Andlauer, Olivier
# Simon, Noah
# Mignot, Emmanuel
#
# <Article PMID: 24560679>
# 2014-12-08
# Bian, Jiang
# Xie, Mengjun
# Topaloglu, Umit
# Hudson, Teresa
# Eswaran, Hari
# Hogan, William
#
# <Article PMID: 24555103>
# 2014-02-24
# Chakraborty, Sandeep
# Venkatramani, Ravindra
# Rao, Basuthkar J
# Asgeirsson, Bjarni
# Dandekar, Abhaya M
#
# <Article PMID: 24532725>
# 2014-06-16
# Quang, Daniel
# Xie, Xiaohui
#
# <Article PMID: 24532723>
# 2014-06-16
# Eng, Kevin H
# Hanlon, Bret M
#
# <Article PMID: 24532721>
# 2014-06-16
# Pyatkov, Maxim I
# Pankratov, Anton N
#
# <Article PMID: 24526831>
# 2014-02-14
# Tang, Dongming
# Wang, Mingwen
# Zheng, Weifan
# Wang, Hongjun
#
# <Article PMID: 24516375>
# 2014-02-11
# Pitkänen, Esa
# Jouhten, Paula
# Hou, Jian
# Syed, Muhammad Fahad
# Blomberg, Peter
# Kludas, Jana
# Oja, Merja
# Holm, Liisa
# Penttilä, Merja
# Rousu, Juho
# Arvas, Mikko
#
# <Article PMID: 24511145>
# 2014-02-10
# Heasly, Benjamin S
# Cottaris, Nicolas P
# Lichtman, Daniel P
# Xiao, Bei
# Brainard, David H
#
# <Article PMID: 24502833>
# 2014-02-12
# Lammers, Youri
# Peelen, Tamara
# Vos, Rutger A
# Gravendeel, Barbara
#
# <Article PMID: 24501098>
# 2014-05-22
# Halper-Stromberg, Eitan
# Steranka, Jared
# Burns, Kathleen H
# Sabunciyan, Sarven
# Irizarry, Rafael A
#
# <Article PMID: 24493035>
# 2014-05-22
# Maienschein-Cline, Mark
# Lei, Zhengdeng
# Gardeux, Vincent
# Abbasi, Taimur
# Machado, Roberto F
# Gordeuk, Victor
# Desai, Ankit A
# Saraf, Santosh
# Bahroos, Neil
# Lussier, Yves
#
# <Article PMID: 24489371>
# 2014-05-22
# Lott, Paul C
# Korf, Ian
#
# <Article PMID: 24484323>
# 2014-02-11
# Jiao, Wei
# Vembu, Shankar
# Deshwar, Amit G
# Stein, Lincoln
# Morris, Quaid
#
# <Article PMID: 24480439>
# 2014-04-02
# Such-Sanmartín, Gerard
# Sidoli, Simone
# Ventura-Espejo, Estela
# Jensen, Ole N
#
# <Article PMID: 24478338>
# 2014-05-12
# Izquierdo-Carrasco, Fernando
# Cazes, John
# Smith, Stephen A
# Stamatakis, Alexandros
#
# <Article PMID: 24474170>
# 2014-03-24
# Wagih, Omar
# Parts, Leopold
#
# <Article PMID: 24472558>
# 2014-02-12
# Cieślik, Marcin
# Bekiranov, Stefan
#
# <Article PMID: 24470576>
# 2014-05-12
# Buske, Fabian A
# French, Hugh J
# Smith, Martin A
# Clark, Susan J
# Bauer, Denis C
#
# <Article PMID: 24470571>
# 2014-05-12
# Pedersen, Michael
# Oury, Nicolas
# Gravill, Colin
# Phillips, Andrew
#
# <Article PMID: 24458950>
# 2014-05-12
# Fumagalli, Matteo
# Vieira, Filipe G
# Linderoth, Tyler
# Nielsen, Rasmus
#
# <Article PMID: 24399965>
# 2014-01-08
# Krell, Mario M
# Straube, Sirko
# Seeland, Anett
# Wöhrle, Hendrik
# Teiwes, Johannes
# Metzen, Jan H
# Kirchner, Elsa A
# Kirchner, Frank
#
# <Article PMID: 24398039>
# 2014-06-17
# Frazee, Alyssa C
# Sabunciyan, Sarven
# Hansen, Kasper D
# Irizarry, Rafael A
# Leek, Jeffrey T
#
# <Article PMID: 24371154>
# 2014-03-28
# Niu, Beifang
# Ye, Kai
# Zhang, Qunyuan
# Lu, Charles
# Xie, Mingchao
# McLellan, Michael D
# Wendl, Michael C
# Ding, Li
#
# <Article PMID: 24363381>
# 2014-03-28
# Aldecoa, Rodrigo
# Marín, Ignacio
#
# <Article PMID: 24363378>
# 2014-03-28
# Wu, Eric
# Nance, Tracy
# Montgomery, Stephen B
#
# <Article PMID: 24363377>
# 2014-03-28
# Zerbino, Daniel R
# Johnson, Nathan
# Juettemann, Thomas
# Wilder, Steven P
# Flicek, Paul
#
# <Article PMID: 24348509>
# 2013-12-18
# Kumar, Sujai
# Jones, Martin
# Koutsovoulos, Georgios
# Clarke, Michael
# Blaxter, Mark
#
# <Article PMID: 24336412>
# 2014-02-20
# Fernandes, Francisco
# Freitas, Ana T
#
# <Article PMID: 24324759>
# 2013-12-10
# Zhao, Mengyao
# Lee, Wan-Ping
# Garrison, Erik P
# Marth, Gabor T
#
# <Article PMID: 24319000>
# 2014-02-20
# Zhu, Hongjie
# Luo, Man
#
# <Article PMID: 24316132>
# 2014-03-17
# Galardini, Marco
# Mengoni, Alessio
# Biondi, Emanuele G
# Semeraro, Roberto
# Florio, Alessandro
# Bazzicalupo, Marco
# Benedetti, Anna
# Mocali, Stefano
#
# <Article PMID: 24314033>
# 2014-01-07
# Roberts, Adam
# Feng, Harvey
# Pachter, Lior
#
# <Article PMID: 24297520>
# 2014-02-20
# Leggett, Richard M
# Clavijo, Bernardo J
# Clissold, Leah
# Clark, Matthew D
# Caccamo, Mario
#
# <Article PMID: 24281695>
# 2014-01-16
# Turro, Ernest
# Astle, William J
# Tavaré, Simon
#
# <Article PMID: 24262214>
# 2014-01-16
# Ochoa, Rodrigo
# Davies, Mark
# Papadatos, George
# Atkinson, Francis
# Overington, John P
#
# <Article PMID: 24211736>
# 2014-02-25
# Travis, Anthony J
# Moody, Jonathan
# Helwak, Aleksandra
# Tollervey, David
# Kudla, Grzegorz
#
# <Article PMID: 24192544>
# 2014-03-19
# Holt, Carson
# Losic, Bojan
# Pai, Deepa
# Zhao, Zhen
# Trinh, Quang
# Syam, Sujata
# Arshadi, Niloofar
# Jang, Gun Ho
# Ali, Johar
# Beck, Tim
# McPherson, John
# Muthuswamy, Lakshmi B
#
# <Article PMID: 24191071>
# 2013-12-19
# Landis, Michael J
# Bedford, Trevor
#
# <Article PMID: 24177719>
# 2014-03-19
# Croset, Samuel
# Overington, John P
# Rebholz-Schuhmann, Dietrich
#
# <Article PMID: 24177716>
# 2014-03-19
# Jaeger, Daniel
# Barth, Johannes
# Niehues, Anna
# Fufezan, Christian
#
# <Article PMID: 24162466>
# 2014-03-19
# Seoane, José A
# Day, Ian N M
# Gaunt, Tom R
# Campbell, Colin
#
# <Article PMID: 24162465>
# 2014-03-19
# Omasits, Ulrich
# Ahrens, Christian H
# Müller, Sebastian
# Wollscheid, Bernd
#
# <Article PMID: 24152167>
# 2014-01-07
# Pang, Chi Nam Ignatius
# Tay, Aidan P
# Aya, Carlos
# Twine, Natalie A
# Harkness, Linda
# Hart-Smith, Gene
# Chia, Samantha Z
# Chen, Zhiliang
# Deshpande, Nandan P
# Kaakoush, Nadeem O
# Mitchell, Hazel M
# Kassem, Moustapha
# Wilkins, Marc R
#
# <Article PMID: 24148309>
# 2014-01-17
# Sławek, Janusz
# Arodź, Tomasz
#
# <Article PMID: 24128146>
# 2014-03-04
# Bacci, G
# Bazzicalupo, M
# Benedetti, A
# Mengoni, A
#
# <Article PMID: 24124417>
# 2013-10-14
# Cockfield, Jeremy
# Su, Kyungmin
# Robbins, Kay A
#
# <Article PMID: 24123672>
# 2014-02-26
# Rodriguez-R, Luis M
# Konstantinidis, Konstantinos T
#
# <Article PMID: 24078712>
# 2013-12-19
# Bock, Matthias
# Scharp, Till
# Talnikar, Chaitanya
# Klipp, Edda
#
# <Article PMID: 24078702>
# 2013-11-29
# Wang, Tao
# Liu, Jie
# Shen, Li
# Tonti-Filippini, Julian
# Zhu, Yun
# Jia, Haiyang
# Lister, Ryan
# Whitaker, John W
# Ecker, Joseph R
# Millar, A Harvey
# Ren, Bing
# Wang, Wei
#
# <Article PMID: 24068035>
# 2013-11-29
# Ye, Yanbo
# Wei, Bo
# Wen, Lei
# Rayner, Simon
#
# <Article PMID: 24046776>
# 2013-09-18
# Richardson, Emily J
# Escalettes, Franck
# Fotheringham, Ian
# Wallace, Robert J
# Watson, Mick
#
# <Article PMID: 24034598>
# 2013-12-16
# Fisher, Mark A
#
# <Article PMID: 24027418>
# 2013-09-12
# Konganti, Kranti
# Wang, Gang
# Yang, Ence
# Cai, James J
#
# <Article PMID: 24027417>
# 2013-09-12
# Garrigan, Daniel
#
# <Article PMID: 24011402>
# 2013-11-15
# Solovyov, Alexander
# Lipkin, W Ian
#
# <Article PMID: 24008420>
# 2013-10-30
# Tudose, Ilinca
# Hastings, Janna
# Muthukrishnan, Venkatesh
# Owen, Gareth
# Turner, Steve
# Dekker, Adriano
# Kale, Namrata
# Ennis, Marcus
# Steinbeck, Christoph
#
# <Article PMID: 24002108>
# 2013-10-30
# Taylor, Ryan M
# Dance, Jamison
# Taylor, Russ J
# Prince, John T
#
# <Article PMID: 23995393>
# 2013-10-30
# Katayama, Shintaro
# Töhönen, Virpi
# Linnarsson, Sten
# Kere, Juha
#
# <Article PMID: 23987304>
# 2013-11-15
# Itaya, Hidetoshi
# Oshita, Kazuki
# Arakawa, Kazuharu
# Tomita, Masaru
#
# <Article PMID: 23980024>
# 2013-10-21
# Bardet, Anaïs F
# Steinmann, Jonas
# Bafna, Sangeeta
# Knoblich, Juergen A
# Zeitlinger, Julia
# Stark, Alexander
#
# <Article PMID: 23975764>
# 2013-10-21
# Sedlazeck, Fritz J
# Rescheneder, Philipp
# von Haeseler, Arndt
#
# <Article PMID: 23944269>
# 2013-10-11
# Czodrowski, Paul
#
# <Article PMID: 23936070>
# 2013-08-12
# Dorff, Kevin C
# Chambwe, Nyasha
# Zeno, Zachary
# Simi, Manuele
# Shaknovich, Rita
# Campagne, Fabien
#
# <Article PMID: 23925510>
# 2013-10-17
# Szöllõsi, Gergely J
# Rosikiewicz, Wojciech
# Boussau, Bastien
# Tannier, Eric
# Daubin, Vincent
#
# <Article PMID: 23922841>
# 2013-08-07
# Parks, Donovan H
# Mankowski, Timothy
# Zangooei, Somayyeh
# Porter, Michael S
# Armanini, David G
# Baird, Donald J
# Langille, Morgan G I
# Beiko, Robert G
#
# <Article PMID: 23904992>
# 2013-08-01
# Macmanes, Matthew D
# Eisen, Michael B
#
# <Article PMID: 23904198>
# 2013-10-10
# Polvi, Anne
# Linturi, Henna
# Varilo, Teppo
# Anttonen, Anna-Kaisa
# Byrne, Myles
# Fokkema, Ivo F A C
# Almusa, Henrikki
# Metzidis, Anthony
# Avela, Kristiina
# Aula, Pertti
# Kestilä, Marjo
# Muilu, Juha
#
# <Article PMID: 23894185>
# 2013-07-29
# Wiley, Laura K
# Sivley, R Michael
# Bush, William S
#
# <Article PMID: 23875683>
# 2013-08-06
# Trinh, Quang M
# Jen, Fei-Yang Arthur
# Zhou, Ziru
# Chu, Kar Ming
# Perry, Marc D
# Kephart, Ellen T
# Contrino, Sergio
# Ruzanov, Peter
# Stein, Lincoln D
#
# <Article PMID: 23849037>
# 2013-07-22
# Dexter, Daniel
# Brown, Daniel G
#
# <Article PMID: 23825371>
# 2013-09-20
# Smith, Rob
# Anthonymuthu, Tamil S
# Ventura, Dan
# Prince, John T
#
# <Article PMID: 23821651>
# 2013-08-28
# Nariai, Naoki
# Hirose, Osamu
# Kojima, Kaname
# Nagasaki, Masao
#
# <Article PMID: 23816174>
# 2013-07-02
# Ustek, Dilan
# Kohrman, Abraham
# Krstic, Bogdan
# Fernandez, Karissa
#
# <Article PMID: 23813006>
# 2013-07-01
# Huang, Lin
# Popic, Victoria
# Batzoglou, Serafim
#
# <Article PMID: 23799126>
# 2013-06-26
# Eren, A Murat
# Vineis, Joseph H
# Morrison, Hilary G
# Sogin, Mitchell L
#
# <Article PMID: 23796449>
# 2013-07-22
# Kontopoulos, Dimitrios-Georgios
# Glykos, Nicholas M
#
# <Article PMID: 23766418>
# 2013-08-13
# May, John W
# James, A Gordon
# Steinbeck, Christoph
#
# <Article PMID: 23735186>
# 2013-06-05
# Li, Yi
# Xie, Xiaohui
#
# <Article PMID: 23734743>
# 2013-06-05
# Biesinger, Jacob
# Wang, Yuanfeng
# Xie, Xiaohui
#
# <Article PMID: 23734710>
# 2013-06-05
# Ander, Christina
# Schulz-Trieglaff, Ole B
# Stoye, Jens
# Cox, Anthony J
#
# <Article PMID: 23749959>
# 2013-07-17
# Etherington, Graham J
# MacLean, Daniel
#
# <Article PMID: 23748955>
# 2013-06-24
# Medina, Ignacio
# Salavert, Francisco
# Sanchez, Rubén
# de Maria, Alejandro
# Alonso, Roberto
# Escobar, Pablo
# Bleda, Marta
# Dopazo, Joaquín
#
# <Article PMID: 23736531>
# 2013-07-17
# Nordell Markovits, Alexei
# Joly Beauparlant, Charles
# Toupin, Dominique
# Wang, Shengrui
# Droit, Arnaud
# Gevry, Nicolas
#
# <Article PMID: 23736529>
# 2013-07-26
# Raczy, Come
# Petrovski, Roman
# Saunders, Christopher T
# Chorny, Ilya
# Kruglyak, Semyon
# Margulies, Elliott H
# Chuang, Han-Yu
# Källberg, Morten
# Kumar, Swathi A
# Liao, Arnold
# Little, Kristina M
# Strömberg, Michael P
# Tanner, Stephen W
#
# <Article PMID: 23735196>
# 2013-06-05
# Callahan, Alison
# Cruz-Toledo, José
# Dumontier, Michel
#
# <Article PMID: 23734675>
# 2013-06-05
# Soldatova, Larisa N
# Rzhetsky, Andrey
# De Grave, Kurt
# King, Ross D
#
# <Article PMID: 23705851>
# 2013-05-31
# Smith, Graham R
# Shanley, Daryl P
#
# <Article PMID: 23688306>
# 2013-06-17
# Rasmussen, Simon H
# Jacobsen, Anders
# Krogh, Anders
#
# <Article PMID: 23668630>
# 2013-06-03
# Stoltzfus, Arlin
# Lapp, Hilmar
# Matasci, Naim
# Deus, Helena
# Sidlauskas, Brian
# Zmasek, Christian M
# Vaidya, Gaurav
# Pontelli, Enrico
# Cranston, Karen
# Vos, Rutger
# Webb, Campbell O
# Harmon, Luke J
# Pirrung, Megan
# O'Meara, Brian
# Pennell, Matthew W
# Mirarab, Siavash
# Rosenberg, Michael S
# Balhoff, James P
# Bik, Holly M
# Heath, Tracy A
# Midford, Peter E
# Brown, Joseph W
# McTavish, Emily Jane
# Sukumaran, Jeet
# Westneat, Mark
# Alfaro, Michael E
# Steele, Aaron
# Jordan, Greg
#
# <Article PMID: 23661694>
# 2013-12-19
# Janin, Lilian
# Rosone, Giovanna
# Cox, Anthony J
#
# <Article PMID: 23661685>
# 2013-07-16
# Hahn, Christoph
# Bachmann, Lutz
# Chevreux, Bastien
#
# <Article PMID: 23630581>
# 2013-04-30
# McMurdie, Paul J
# Holmes, Susan
#
# <Article PMID: 23630176>
# 2013-07-01
# Sloggett, Clare
# Goonasekera, Nuwan
# Afgan, Enis
#
# <Article PMID: 23620360>
# 2013-06-06
# Hansen, Nancy F
# Gartner, Jared J
# Mei, Lan
# Samuels, Yardena
# Mullikin, James C
#
# <Article PMID: 23620359>
# 2013-07-01
# Barann, Matthias
# Esser, Daniela
# Klostermeier, Ulrich C
# Lappalainen, Tuuli
# Luzius, Anne
# Kuiper, Jan W P
# Ammerpohl, Ole
# Vater, Inga
# Siebert, Reiner
# Amstislavskiy, Vyacheslav
# Sudbrak, Ralf
# Lehrach, Hans
# Schreiber, Stefan
# Rosenstiel, Philip
#
# <Article PMID: 23620357>
# 2013-05-23
# O'Fallon, Brendan D
# Wooderchak-Donahue, Whitney
# Crockett, David K
#
# <Article PMID: 23613487>
# 2013-07-01
# Jónsson, Hákon
# Ginolhac, Aurélien
# Schubert, Mikkel
# Johnson, Philip L F
# Orlando, Ludovic
#
# <Article PMID: 23595665>
# 2013-06-06
# Sommer, Christoph
# Held, Michael
# Fischer, Bernd
# Huber, Wolfgang
# Gerlich, Daniel W
#
# <Article PMID: 23587322>
# 2013-04-16
# Lynch, Michael Dj
# Masella, Andre P
# Hall, Michael W
# Bartram, Andrea K
# Neufeld, Josh D
#
# <Article PMID: 23559640>
# 2013-05-23
# Fusi, Nicoló
# Lippert, Christoph
# Borgwardt, Karsten
# Lawrence, Neil D
# Stegle, Oliver
#
# <Article PMID: 23516341>
# 2013-03-21
# Feng, Zhixing
# Fang, Gang
# Korlach, Jonas
# Clark, Tyson
# Luong, Khai
# Zhang, Xuegong
# Wong, Wing
# Schadt, Eric
#
# <Article PMID: 23508994>
# 2013-05-22
# Wagner, Alex H
# Taylor, Kyle R
# DeLuca, Adam P
# Casavant, Thomas L
# Mullins, Robert F
# Stone, Edwin M
# Scheetz, Todd E
# Braun, Terry A
#
# <Article PMID: 23506117>
# 2013-05-31
# Perry, Andrew J
# Ho, Bosco K
#
# <Article PMID: 23505295>
# 2013-05-16
# Hickey, Glenn
# Paten, Benedict
# Earl, Dent
# Zerbino, Daniel
# Haussler, David
#
# <Article PMID: 23505292>
# 2013-04-25
# Croset, Samuel
# Overington, John P
# Rebholz-Schuhmann, Dietrich
#
# <Article PMID: 23489488>
# 2013-03-25
# Zheng, Yi-Bao
# Zhang, Zhi-Min
# Liang, Yi-Zeng
# Zhan, De-Jian
# Huang, Jian-Hua
# Yun, Yong-Huan
# Xie, Hua-Lin
#
# <Article PMID: 23471301>
# 2013-04-25
# Guo, Yan
# Li, Jiang
# Li, Chung-I
# Shyr, Yu
# Samuels, David C
#
# <Article PMID: 23471004>
# 2013-04-15
# Shiraishi, Yuichi
# Sato, Yusuke
# Chiba, Kenichi
# Okuno, Yusuke
# Nagata, Yasunobu
# Yoshida, Kenichi
# Shiba, Norio
# Hayashi, Yasuhide
# Kume, Haruki
# Homma, Yukio
# Sanada, Masashi
# Ogawa, Seishi
# Miyano, Satoru
#
# <Article PMID: 23469199>
# 2013-03-07
# Costea, Paul Igor
# Lundeberg, Joakim
# Akan, Pelin
#
# <Article PMID: 23437047>
# 2013-02-25
# Ebrahimpour, Maryam
# Putniņš, Tālis J
# Berryman, Matthew J
# Allison, Andrew
# Ng, Brian W-H
# Abbott, Derek
#
# <Article PMID: 23419376>
# 2013-04-15
# Gehlenborg, Nils
# Noble, Michael S
# Getz, Gad
# Chin, Lynda
# Park, Peter J
#
# <Article PMID: 23413434>
# 2013-04-15
# Kim, Sangwoo
# Jeong, Kyowon
# Bafna, Vineet
#
# <Article PMID: 23393584>
# 2013-02-08
# Bull, Simon C
# Muldoon, Mark R
# Doig, Andrew J
#
# <Article PMID: 23365411>
# 2013-03-25
# Cronkite-Ratcliff, Bryce
# Pande, Vijay
#
# <Article PMID: 23335939>
# 2013-01-21
# Nellore, Abhinav
# Bobkov, Konstantin
# Howe, Elizabeth
# Pankov, Aleksandr
# Diaz, Aaron
# Song, Jun S
#
# <Article PMID: 23335014>
# 2013-02-27
# Arunapuram, Preeti
# Edvardsson, Ingolfur
# Golden, Michael
# Anderson, James W J
# Novák, Adám
# Sükösd, Zsuzsanna
# Hein, Jotun
#
# <Article PMID: 23324024>
# 2013-01-25
# Boyle, Brad
# Hopkins, Nicole
# Lu, Zhenyuan
# Raygoza Garay, Juan Antonio
# Mozzherin, Dmitry
# Rees, Tony
# Matasci, Naim
# Narro, Martha L
# Piel, William H
# McKay, Sheldon J
# Lowry, Sonya
# Freeland, Chris
# Peet, Robert K
# Enquist, Brian J
#
# <Article PMID: 23320958>
# 2014-08-01
# Treangen, Todd J
# Koren, Sergey
# Sommer, Daniel D
# Liu, Bo
# Astrovskaya, Irina
# Ondov, Brian
# Darling, Aaron E
# Phillippy, Adam M
# Pop, Mihai
#
# <Article PMID: 23303508>
# 2013-02-27
# Thomas, Niclas
# Heather, James
# Ndifon, Wilfred
# Shawe-Taylor, John
# Chain, Benjamin
#
# <Article PMID: 23282094>
# 2013-01-03
# Chang, Yu-Jung
# Chen, Chien-Chih
# Chen, Chuen-Liang
# Ho, Jan-Ming
#
# <Article PMID: 25506420>
# 2014-12-19
# Chakraborty, Sandeep
# Venkatramani, Ravindra
# Rao, Basuthkar J
# Asgeirsson, Bjarni
# Dandekar, Abhaya M
#
# <Article PMID: 24627786>
# 2014-03-17
# Chakraborty, Sandeep
#
# <Article PMID: 23272111>
# 2012-12-28
# Zakrzewski, Piotr
# Medema, Marnix H
# Gevorgyan, Albert
# Kierzek, Andrzej M
# Breitling, Rainer
# Takano, Eriko
#
# <Article PMID: 23267176>
# 2013-02-13
# Maguire, Eamonn
# González-Beltrán, Alejandra
# Whetzel, Patricia L
# Sansone, Susanna-Assunta
# Rocca-Serra, Philippe
#
# <Article PMID: 23267174>
# 2013-02-13
# McDavid, Andrew
# Finak, Greg
# Chattopadyay, Pratip K
# Dominguez, Maria
# Lamoreaux, Laurie
# Ma, Steven S
# Roederer, Mario
# Gottardo, Raphael
#
# <Article PMID: 23239673>
# 2013-02-13
# Medlar, Alan
# Głowacka, Dorota
# Stanescu, Horia
# Bryson, Kevin
# Kleta, Robert
#
# <Article PMID: 23236265>
# 2012-12-13
# Mosaliganti, Kishore R
# Noche, Ramil R
# Xiong, Fengzhu
# Swinburne, Ian A
# Megason, Sean G
#
# <Article PMID: 23233656>
# 2013-01-31
# Keane, Thomas M
# Wong, Kim
# Adams, David J
#
# <Article PMID: 23220575>
# 2013-01-31
# Pak, Theodore R
# Roth, Frederick P
#
# <Article PMID: 23220574>
# 2013-01-31
# McCoy, Connor O
# Gallagher, Aaron
# Hoffman, Noah G
# Matsen, Frederick A
#
# <Article PMID: 23202745>
# 2012-12-21
# Huang, Hailiang
# Tata, Sandeep
# Prill, Robert J
#
# <Article PMID: 23180795>
# 2012-12-20
# Pizarro, Angel
# Hayer, Katharina
# Lahens, Nicholas F
# Hogenesch, John B
#
# <Article PMID: 23178637>
# 2013-01-17
# Spjuth, Ola
# Georgiev, Valentin
# Carlsson, Lars
# Alvarsson, Jonathan
# Berg, Arvid
# Willighagen, Egon
# Wikberg, Jarl E S
# Eklund, Martin
#
# <Article PMID: 23172864>
# 2013-01-31
# Miller, Chase A
# Anthony, Jon
# Meyer, Michelle M
# Marth, Gabor
#
# <Article PMID: 23172860>
# 2013-01-17
# Pervouchine, Dmitri D
# Knowles, David G
# Guigó, Roderic
#
# <Article PMID: 23162057>
# 2013-01-17
# Zschaler, Gerd
# Gross, Thilo
#
# <Article PMID: 23129298>
# 2012-12-21
# Layer, Ryan M
# Skadron, Kevin
# Robins, Gabriel
# Hall, Ira M
# Quinlan, Aaron R
#
# <Article PMID: 23090981>
# 2012-12-28
# Highnam, Gareth
# Franck, Christopher
# Martin, Andy
# Stephens, Calvin
# Puthige, Ashwin
# Mittelman, David
#
# <Article PMID: 23071651>
# 2012-10-16
# Hird, Sarah M
#
# <Article PMID: 23068444>
# 2014-08-01
# Diaz, Aaron
# Nellore, Abhinav
# Song, Jun S
#
# <Article PMID: 23023981>
# 2012-11-29
# Frech, Christian
# Choo, Caleb
# Chen, Nansheng
#
# <Article PMID: 22994508>
# 2013-01-11
# Mishima, Hiroyuki
# Aerts, Jan
# Katayama, Toshiaki
# Bonnal, Raoul J P
# Yoshiura, Koh-ichiro
#
# <Article PMID: 22962493>
# 2012-09-10
# Ng, Sam
# Collisson, Eric A
# Sokolov, Artem
# Goldstein, Theodore
# Gonzalez-Perez, Abel
# Lopez-Bigas, Nuria
# Benz, Christopher
# Haussler, David
# Stuart, Joshua M
#
# <Article PMID: 22962343>
# 2012-11-12
# Pietzsch, Tobias
# Preibisch, Stephan
# Tomancák, Pavel
# Saalfeld, Stephan
#
# <Article PMID: 22957556>
# 2012-09-10
# Varilly, Patrick
# Angioletti-Uberti, Stefano
# Mognetti, Bortolo M
# Frenkel, Daan
#
# <Article PMID: 22954632>
# 2012-11-12
# Pedersen, Brent S
# Schwartz, David A
# Yang, Ivana V
# Kechris, Katerina J
#
# <Article PMID: 22942017>
# 2012-10-22
# Cheng, Tiejun
# Wang, Yanli
# Bryant, Stephen H
#
# <Article PMID: 22923455>
# 2012-08-27
# Sahlin, Kristoffer
# Street, Nathaniel
# Lundeberg, Joakim
# Arvestad, Lars
#
# <Article PMID: 22908216>
# 2012-10-11
# Smith, Stephen A
# O'Meara, Brian C
#
# <Article PMID: 22880129>
# 2012-08-10
# Sun, Zheng
# Tian, Weidong
#
# <Article PMID: 22851531>
# 2012-10-11
# Rojas-Chertó, Miguel
# van Vliet, Michael
# Peironcely, Julio E
# van Doorn, Ronnie
# Kooyman, Maarten
# te Beek, Tim
# van Driel, Marc A
# Hankemeier, Thomas
# Reijmers, Theo
#
# <Article PMID: 22764160>
# 2012-08-27
# Santamaría, Rodrigo
# Pierre, Philippe
#
# <Article PMID: 22752048>
# 2012-10-17
# Collins, R Eric
# Higgs, Paul G
#
# <Article PMID: 22730433>
# 2012-08-08
# Otegui, Javier
# Ariño, Arturo H
#
# <Article PMID: 22712439>
# 2012-11-26
# Wu, Steven H
# Black, Michael A
# North, Robyn A
# Rodrigo, Allen G
#
# <Article PMID: 22711784>
# 2012-12-05
# Wang, Jianxin
# Chen, Gang
# Liu, Binbin
# Li, Min
# Pan, Yi
#
# <Article PMID: 22689644>
# 2012-06-28
# Qu, Wubin
# Zhou, Yang
# Zhang, Yanchun
# Lu, Yiming
# Wang, Xiaolei
# Zhao, Dongsheng
# Yang, Yi
# Zhang, Chenggang
#
# <Article PMID: 22628524>
# 2012-07-06
# Chibon, Pierre-Yves
# Schoof, Heiko
# Visser, Richard G F
# Finkers, Richard
#
# <Article PMID: 22628519>
# 2012-07-23
# Stamatakis, A
# Aberer, A J
# Goll, C
# Smith, S A
# Berger, S A
# Izquierdo-Carrasco, F
#
# <Article PMID: 22595209>
# 2012-07-23
# Ge, Yongchao
# Sealfon, Stuart C
#
# <Article PMID: 22576174>
# 2012-07-06
# Langille, Morgan G I
# Laird, Matthew R
# Hsiao, William W L
# Chiu, Terry A
# Eisen, Jonathan A
# Brinkman, Fiona S L
#
# <Article PMID: 22569178>
# 2012-07-06
# Li, Heng
#
# <Article PMID: 22556367>
# 2012-06-12
# Brandizi, Marco
# Kurbatova, Natalja
# Sarkans, Ugis
# Rocca-Serra, Philippe
#
# <Article PMID: 22556365>
# 2012-05-22
# Cox, Anthony J
# Bauer, Markus J
# Jakobi, Tobias
# Rosone, Giovanna
#
# <Article PMID: 22551205>
# 2012-07-12
# Almeida, Jonas S
# Grüneberg, Alexander
# Maass, Wolfgang
# Vinga, Susana
#
# <Article PMID: 22539671>
# 2012-06-12
# Cereto-Massagué, Adrià
# Guasch, Laura
# Valls, Cristina
# Mulero, Miquel
# Pujadas, Gerard
# Garcia-Vallvé, Santiago
#
# <Article PMID: 22370965>
# 2014-11-03
# Pool, René
# Heringa, Jaap
# Hoefling, Martin
# Schulz, Roland
# Smith, Jeremy C
# Feenstra, K Anton
#
# <Article PMID: 22302574>
# 2012-04-02
# Sun, Ruping
# Love, Michael I
# Zemojtel, Tomasz
# Emde, Anne-Katrin
# Chung, Ho-Ryun
# Vingron, Martin
# Haas, Stefan A
#
# <Article PMID: 22302572>
# 2012-04-02
# Bald, Till
# Barth, Johannes
# Niehues, Anna
# Specht, Michael
# Hippler, Michael
# Fufezan, Christian
#
# <Article PMID: 22279150>
# 2012-02-16
# Bida, John Paul
# Maher, L James
#
# <Article PMID: 22238257>
# 2012-03-01
# Hentrich, Thomas
# Schulze, Julia M
# Emberly, Eldon
# Kobor, Michael S
#
# <Article PMID: 22235263>
# 2012-01-11
# Peltola, Tomi
# Marttinen, Pekka
# Jula, Antti
# Salomaa, Veikko
# Perola, Markus
# Vehtari, Aki
#
# <Article PMID: 22215819>
# 2012-03-01
# Mørk, Søren
# Holmes, Ian
#
# <Article PMID: 25328913>
# 2014-10-20
# Fenwick, Matthew
# Sesanker, Colbert
# Schiller, Martin R
# Ellis, Heidi Jc
# Hinman, M Lee
# Vyas, Jay
# Gryk, Michael R
#
# <Article PMID: 22151646>
# 2011-12-13
# Lv, Jie
# Havlak, Paul
# Putnam, Nicholas H
#
# <Article PMID: 22080292>
# 2012-03-07
# Langer, Steve G
#
# <Article PMID: 22017798>
# 2012-01-06
# Pinello, Luca
# Lo Bosco, Giosuè
# Hanlon, Bret
# Yuan, Guo-Cheng
#
# <Article PMID: 21994228>
# 2011-12-13
# Riba-Grognuz, Oksana
# Keller, Laurent
# Falquet, Laurent
# Xenarios, Ioannis
# Wurm, Yannick
#
# <Article PMID: 21911333>
# 2011-10-06
# Bielejec, Filip
# Rambaut, Andrew
# Suchard, Marc A
# Lemey, Philippe
#
# <Article PMID: 21899774>
# 2011-09-29
# Mishima, Hiroyuki
# Sasaki, Kensaku
# Tanaka, Masahiro
# Tatebe, Osamu
# Yoshiura, Koh-Ichiro
#
# <Article PMID: 21824426>
# 2011-09-12
# Jethava, Vinay
# Bhattacharyya, Chiranjib
# Dubhashi, Devdatt
# Vemuri, Goutham N
#
# <Article PMID: 21724594>
# 2011-08-19
# Pedersen, Brent
# Hsieh, Tzung-Fu
# Ibarra, Christian
# Fischer, Robert L
#
# <Article PMID: 21685055>
# 2011-08-05
# Bolouri, Hamid
# Dulepet, Rajiv
# Angerman, Michael
#
# <Article PMID: 21685051>
# 2011-08-05
# Xin, Yurong
# Ge, Yongchao
# Haghighi, Fatemeh G
#
# <Article PMID: 21635747>
# 2011-06-28
# Blanca, Jose M
# Pascual, Laura
# Ziarsolo, Peio
# Nuez, Fernando
# Cañizares, Joaquin
#
# <Article PMID: 21595876>
# 2011-10-20
# Miller, Christopher S
# Baker, Brett J
# Thomas, Brian C
# Singer, Steven W
# Banfield, Jillian F
#
# <Article PMID: 21529350>
# 2011-05-26
# Oshita, Kazuki
# Arakawa, Kazuharu
# Tomita, Masaru
#
# <Article PMID: 21501495>
# 2011-05-09
# Tang, Haibao
# Lyons, Eric
# Pedersen, Brent
# Schnable, James C
# Paterson, Andrew H
# Freeling, Michael
#
# <Article PMID: 21493652>
# 2011-06-03
# Barnett, Derek W
# Garrison, Erik K
# Quinlan, Aaron R
# Strömberg, Michael P
# Marth, Gabor T
#
# <Article PMID: 21478170>
# 2011-08-09
# Gardner, Paul P
# Barquist, Lars
# Bateman, Alex
# Nawrocki, Eric P
# Weinberg, Zasha
#
# <Article PMID: 21357752>
# 2011-03-22
# Washietl, Stefan
# Findeiss, Sven
# Müller, Stephan A
# Kalkhof, Stefan
# von Bergen, Martin
# Hofacker, Ivo L
# Stadler, Peter F
# Goldman, Nick
#
# <Article PMID: 21296748>
# 2011-03-30
# Pedersen, Brent S
# Tang, Haibao
# Freeling, Michael
#
# <Article PMID: 21169373>
# 2011-02-10
# Gostev, Mikhail
# Fernandez-Banet, Julio
# Rung, Johan
# Dietrich, Joern
# Prokopenko, Inga
# Ripatti, Samuli
# McCarthy, Mark I
# Brazma, Alvis
# Krestyaninova, Maria
#
# <Article PMID: 21124986>
# 2010-12-02
# Miller, Andrew K
# Print, Cristin G
# Nielsen, Poul M F
# Crampin, Edmund J
#
# <Article PMID: 20935049>
# 2010-12-23
# Bombarely, Aureliano
# Menda, Naama
# Tecle, Isaak Y
# Buels, Robert M
# Strickler, Susan
# Fischer-York, Thomas
# Pujar, Anuradha
# Leto, Jonathan
# Gosselin, Joseph
# Mueller, Lukas A
#
# <Article PMID: 20798169>
# 2010-10-08
# Goll, Johannes
# Rusch, Douglas B
# Tanenbaum, David M
# Thiagarajan, Mathangi
# Li, Kelvin
# Methé, Barbara A
# Yooseph, Shibu
#
# <Article PMID: 20562450>
# 2010-08-06
# Kondrashov, Alexey S
# Assis, Raquel
#
# <Article PMID: 20529912>
# 2010-06-09
# Vaske, Charles J
# Benz, Stephen C
# Sanborn, J Zachary
# Earl, Dent
# Szeto, Christopher
# Zhu, Jingchun
# Haussler, David
# Stuart, Joshua M
#
# <Article PMID: 20421198>
# 2010-06-09
# Sukumaran, Jeet
# Holder, Mark T
#
# <Article PMID: 20106815>
# 2010-03-08
# Piipari, Matias
# Down, Thomas A
# Saini, Harpreet
# Enright, Anton
# Hubbard, Tim J P

# %% [markdown]
# ### Getting Author Order
#
# Author position matters, but it matters in sort of a weird way - first author and last author are most important, then decreasing as you work your way in to the middle of the list. But practically, there's not much distinction between 3rd and 4th author (or 3rd from last and 4th from last), so we'll generate scores for first, second, last, penultimate and everyone else. The trick is to avoid index errors if the author list is smaller than 5, so we need to write up some special cases.

# %%
def score_authors(author_list):
    if not author_list:
        first = None
    else:
        first = author_list[0]
    others, penultimate, second, last = None, None, None, None
    
    list_length = len(author_list)
    if list_length > 4:
        others = [author for author in author_list[2:-2]]
    if list_length > 3:
        penultimate = author_list[-2]
    if list_length > 2:
        second = author_list[1]
    if list_length > 1:
        last = author_list[-1]
        

    return first, last, second, penultimate, others

# %% [markdown]
# ### DataFrame generation
#
# In order to get the data into a usable spreadsheet-like form, and for later analysis, I'm going to use the `DataFrame`s from the [pandas](http://pandas.pydata.org/) package. This might be overkill, but I know how to use it (sort of).

# %%
import pandas as pd

col_names = ["Date", "Journal", "First Author", "Last Author", "Second Author", "Penultimate Author", "Other Authors"]

df = pd.DataFrame()

for article in parse_pubmed_xml('github_pubs.xml'):
    first, last, second, penultimate, others = score_authors(article.authors)
    first = first.first_name
    try:
        last = last.first_name
    except:
        pass
    try:
        second = second.first_name
    except:
        pass
    try:
        penultimate = penultimate.first_name
    except:
        pass
    try:
        others = [x.first_name for x in others]
    except:
        pass
    
    row = pd.Series([article.pubdate, article.journal, first, last, second, penultimate, others],
                    name=article.pmid, index=col_names)
    df = df.append(row)

print(df)
# Out:
#                 Date First Author Journal Last Author  \
# 26357045  2015-09-11     Fumihide    None    Eberhard
# 25601296  2015-01-20     Abhishek    None     Richard
# 25558360  2015-01-05         Sean    None    Lawrence
# 25553811  2015-01-02      Junfang    None    Volkhard
# 25549775  2015-06-09       Simone    None      Andrea
# 25543048  2015-04-28    Guillaume    None     Michael
# 25540185  2015-04-28        Peter    None        None
# 25527832  2015-04-12      Michael    None       Aaron
# 25526884  2015-04-27         Carl    None       Solon
# 25524895  2015-04-28         John    None        Hugo
# 25521965  2014-12-19     Chengkun    None       Goran
# 25520192  2015-01-24         Paul    None      Hisham
# 25514851  2015-02-06        Seyed    None      Jeroen
# 25505094  2015-04-12      Spencer    None     Andreas
# 25505087  2015-04-12       Gunnar    None        Hans
# 25505086  2015-04-12       Daniel    None      Xiaowu
# 25504847  2015-04-12     Bernhard    None       Peter
# 25481009  2015-04-12        Jagir    None       James
# 25481007  2015-04-12         Jeff    None       James
# 25480375  2015-04-12        Chris    None       Roger
# 25474353  2014-12-05    Alexandra    None      Alexei
# 25461763  2014-12-03         Xiao    None      Yadong
# 25452688  2014-12-02     Wan-Ping    None       Gabor
# 25435543  2015-01-31       Quanhu    None        Rong
# 25431162  2015-04-27      Andreas    None      Robert
# 25428347  2015-02-18        Aaron    None         Jun
# 25422674  2014-11-25      Michael    None     Kathryn
# 25414364  2015-04-03        Layla    None      Silvio
# 25414349  2015-02-18     Nicholas    None       Simon
# 25410596  2015-01-07         Todd    None        Adam
# ...              ...          ...     ...         ...
# 22238257  2012-03-01       Thomas    None     Michael
# 22235263  2012-01-11         Tomi    None         Aki
# 22215819  2012-03-01        Søren    None         Ian
# 25328913  2014-10-20      Matthew    None     Michael
# 22151646  2011-12-13          Jie    None    Nicholas
# 22080292  2012-03-07        Steve    None        None
# 22017798  2012-01-06         Luca    None   Guo-Cheng
# 21994228  2011-12-13       Oksana    None     Yannick
# 21911333  2011-10-06        Filip    None    Philippe
# 21899774  2011-09-29     Hiroyuki    None  Koh-Ichiro
# 21824426  2011-09-12        Vinay    None     Goutham
# 21724594  2011-08-19        Brent    None      Robert
# 21685055  2011-08-05        Hamid    None     Michael
# 21685051  2011-08-05       Yurong    None     Fatemeh
# 21635747  2011-06-28         Jose    None     Joaquin
# 21595876  2011-10-20  Christopher    None     Jillian
# 21529350  2011-05-26       Kazuki    None      Masaru
# 21501495  2011-05-09       Haibao    None     Michael
# 21493652  2011-06-03        Derek    None       Gabor
# 21478170  2011-08-09         Paul    None       Zasha
# 21357752  2011-03-22       Stefan    None        Nick
# 21296748  2011-03-30        Brent    None     Michael
# 21169373  2011-02-10      Mikhail    None       Maria
# 21124986  2010-12-02       Andrew    None      Edmund
# 20935049  2010-12-23    Aureliano    None       Lukas
# 20798169  2010-10-08     Johannes    None       Shibu
# 20562450  2010-08-06       Alexey    None      Raquel
# 20529912  2010-06-09      Charles    None      Joshua
# 20421198  2010-06-09         Jeet    None        Mark
# 20106815  2010-03-08       Matias    None         Tim
#
#                                               Other Authors  \
# 26357045                                               None
# 25601296                                               None
# 25558360                                     [Rogier, Jörn]
# 25553811                                           [Ruslan]
# 25549775                                               None
# 25543048                                          [Mathias]
# 25540185                                               None
# 25527832                                               None
# 25526884                                               None
# 25524895                       [Jian, Narges, Mark, Alexej]
# 25521965                                               None
# 25520192                                               None
# 25514851  [Martijn, Michiel, Irina, Yavuz, Ken, Johan, P...
# 25505094                                               None
# 25505087                                          [Florian]
# 25505086  [Lishuang, Marie, Alphons, Douglas, Janey, Marni]
# 25504847                                               None
# 25481009                     [Patrick, Neil, Richard, Alan]
# 25481007                                               None
# 25480375                                 [Gordon, Xiaoquan]
# 25474353                                               None
# 25461763                            [Francis, Siu, Guangri]
# 25452688                                               None
# 25435543                 [Jie, Qingrun, Zhiduan, Yan, Chen]
# 25431162                                               None
# 25428347                                               None
# 25422674              [Lesley-Ann, Mark, Bernard, Takehiro]
# 25414364                                           [Manuel]
# 25414349               [Thomas, Aidan, Jacqueline, Stephen]
# 25410596                                               None
# ...                                                     ...
# 22238257                                               None
# 22235263                                    [Antti, Veikko]
# 22215819                                               None
# 25328913                                 [Martin, Heidi, M]
# 22151646                                               None
# 22080292                                               None
# 22017798                                               None
# 21994228                                          [Laurent]
# 21911333                                               None
# 21899774                                         [Masahiro]
# 21824426                                               None
# 21724594                                               None
# 21685055                                               None
# 21685051                                               None
# 21635747                                             [Peio]
# 21595876                                            [Brian]
# 21529350                                               None
# 21501495                                     [Brent, James]
# 21493652                                            [Aaron]
# 21478170                                             [Alex]
# 21357752                     [Stephan, Stefan, Martin, Ivo]
# 21296748                                               None
# 21169373                 [Johan, Joern, Inga, Samuli, Mark]
# 21124986                                               None
# 20935049  [Isaak, Robert, Susan, Thomas, Anuradha, Jonat...
# 20798169                          [David, Mathangi, Kelvin]
# 20562450                                               None
# 20529912                   [J, Dent, Christopher, Jingchun]
# 20421198                                               None
# 20106815                                         [Harpreet]
#
#          Penultimate Author Second Author
# 26357045               None         Erika
# 25601296               None          None
# 25558360               Andy         Helen
# 25553811               Jörn         Pavlo
# 25549775            Lorenzo          Luca
# 25543048             Arnaud        Nathan
# 25540185               None          None
# 25527832               None           Ira
# 25526884            Laurent         Alice
# 25524895               Wing      Marghoob
# 25521965              Georg     Jean-Marc
# 25520192               None          None
# 25514851              Peter        Lusine
# 25505094               None        Philip
# 25505087             Johann        Ludwig
# 25505086             Mannis        Jeremy
# 25504847               None        Fabian
# 25481009               Hugh         Peter
# 25481007               None          None
# 25480375          Francesca       Gregory
# 25474353              Tanja         David
# 25461763                 Bo         Henry
# 25452688               None       Jiantao
# 25435543                 Yu       Rongxia
# 25431162             Adnane       Tatyana
# 25428347             Miguel           Han
# 25422674             Justin       Harriet
# 25414364              Carlo       Damiano
# 25414349             Julian        Andrew
# 25410596             Sergey         Brian
# ...                     ...           ...
# 22238257              Eldon         Julia
# 22235263             Markus         Pekka
# 22215819               None          None
# 25328913                Jay       Colbert
# 22151646               None          Paul
# 22080292               None          None
# 22017798               Bret        Giosuè
# 21994228            Ioannis       Laurent
# 21911333               Marc        Andrew
# 21899774              Osamu       Kensaku
# 21824426            Devdatt     Chiranjib
# 21724594          Christian      Tzung-Fu
# 21685055               None         Rajiv
# 21685051               None      Yongchao
# 21635747           Fernando         Laura
# 21595876             Steven         Brett
# 21529350               None      Kazuharu
# 21501495             Andrew          Eric
# 21493652            Michael          Erik
# 21478170               Eric          Lars
# 21357752              Peter          Sven
# 21296748               None        Haibao
# 21169373              Alvis         Julio
# 21124986               Poul       Cristin
# 20935049             Joseph         Naama
# 20798169            Barbara       Douglas
# 20562450               None          None
# 20529912              David       Stephen
# 20421198               None          None
# 20106815              Anton        Thomas
#
# [402 rows x 7 columns]

# %% [markdown]
# ## Getting Genders - Prep
# Now the tough part - getting genders.
#
# I played around trying to get `sexmachine` and `GenderComputer` to work, but ran into some issues, and those projects don't seem like they're being maintained, so I thought i'd try [genderize.io](http://genderize.io) and [gender-api.com](gender-api.com). The trouble is these are a web apis, which takes more time than something run locally, and they have a limit to the number of requests you can make. Since there are probably a lot of duplicate names, I thought it might be worth collapsing the names into a set.

# %%
unique_names = set([])

def get_unique_names(xml_file, name_set=None):
    new_names = []
    if not name_set:
        name_set = set([])
    for article in parse_pubmed_xml(xml_file):
        first, last, second, penultimate, others = score_authors(article.authors)
        
        if first:
            fa = first.first_name
        else:
            fa = None
        if last:
            la = last.first_name
        else:
            la = None
        if second:
            sa = second.first_name
        else:
            sa = None
        if penultimate:
            pa = penultimate.first_name
        else:
            pa = None
        if others:
            oa = [o.first_name for o in others]
        else:
            oa = []

        new_names.extend([fa, la, sa, pa, *oa])
    
    return name_set.union(set(new_names))

# %%
print(len(unique_names))
unique_names = get_unique_names('github_pubs.xml', unique_names)
print(len(unique_names))
# Out:
# 0
# 1079

# %% [markdown]
# So now... let's check the other, larger datasets:

# %%
unique_names = get_unique_names('comp-bio-1997-2014.xml', unique_names)
unique_names = get_unique_names('biology-1997-2014.xml', unique_names)

# %% [markdown]
# It took a while to parse all of the biology publications, so I'm just going to save the output from the last cell... Also, a few names came out as single characters, which I'm going to remove, and I'm going to make everything all lower case for consistancy

# %%
print(len(unique_names))
with open('all_names.txt', 'w+') as names_file:
    for name in unique_names:
        names_file.write('{},'.format(name))
# Out:
# 74154

# %%
fixed_names = []
with open('all_names.txt', 'r') as names_file:
    names = names_file.read().split(",")
    
    for name in names:
        if name:
            if len(name) > 1:
                fixed_names.append(name.lower())
fixed_names.sort()
print(len(fixed_names))
# Out:
# 74118

# %% [markdown]
# So now that we have a list of names, we need to get genders. Originally I used genderize.io and gender-api.com, but that was before when I thought I only had ~1000 names. But the module I finally got to work (gender-detector) only works in python2... so on to a [new notebook](../src/gender_detection.ipynb)...

# %% [markdown]
# ## Getting Genders - Stats
#
# Now it's time to start working on stats. Best to get gender assignments into columns along with names. Going to generate csv files with `pandas` in order to do analysis elsewhere. Using similar code from [Data Frame Generation](xml_parsing.ipynb#DataFrame-generation)

# %%
gender_dict = {}

with open('gender_dict.txt', 'r') as in_file:
    keys_and_values = in_file.read().split(',')
    for pair in keys_and_values:
        if pair:
            key, value = pair.split(':')
            gender_dict[key] = value

# %%
  
def get_gender(name):
    """
    Requires `gender_dict`
    """
    name = name.lower()
    if name in gender_dict:
        return gender_dict[name]
    else:
        return None
    

def make_csv_from_xml(xml_file, name):
    col_names = ["Date", "Journal", 
                 "First Author", "Last Author", "Second Author", "Penultimate Author", "Other Authors"]
    df = pd.DataFrame()

    counter = 0
    for article in parse_pubmed_xml(xml_file):
        counter +=1
        print(article)
        first, last, second, penultimate, others = score_authors(article.authors)
        fa = get_gender(first.first_name)
        
        if last:
            la = get_gender(last.first_name)
        else:
            la = None
        if second:
            sa = get_gender(second.first_name)
        else:
            sa = None
        if penultimate:
            pa = get_gender(penultimate.first_name)
        else:
            pa = None
        if others:
            oa = [get_gender(o.first_name) for o in others]
        else:
            oa = []
        
        row = pd.Series([article.pubdate, article.journal, fa, la, sa, pa, oa],
                        name=article.pmid, index=col_names)
        df = df.append(row)
        print(row)
        if counter >4:
            break
#     df.to_csv(name)

# %%
make_csv_from_xml('github_pubs.xml', 'github_pub.csv')
# Out:
# <Article PMID: 26357045>
# Date                  2015-09-11
# Journal                     None
# First Author             unknown
# Last Author                 male
# Second Author             female
# Penultimate Author          None
# Other Authors                 []
# Name: 26357045, dtype: object
# <Article PMID: 25601296>
# Date                  2015-01-20
# Journal                     None
# First Author                male
# Last Author                 male
# Second Author               None
# Penultimate Author          None
# Other Authors                 []
# Name: 25601296, dtype: object
# <Article PMID: 25558360>
# Date                          2015-01-05
# Journal                             None
# First Author                        male
# Last Author                         male
# Second Author                     female
# Penultimate Author               unknown
# Other Authors         [unknown, unknown]
# Name: 25558360, dtype: object
# <Article PMID: 25553811>
# Date                  2015-01-02
# Journal                     None
# First Author             unknown
# Last Author              unknown
# Second Author               male
# Penultimate Author       unknown
# Other Authors             [male]
# Name: 25553811, dtype: object
# <Article PMID: 25549775>
# Date                  2015-06-09
# Journal                     None
# First Author             unknown
# Last Author              unknown
# Second Author            unknown
# Penultimate Author          male
# Other Authors                 []
# Name: 25549775, dtype: object

# %%
make_csv_from_xml('comp-bio-1997-2014.xml', 'compbio_pubs2.csv')
# Out:
# <Article PMID: 26255944>
# Date                                             2015-08-10
# Journal                                                None
# First Author                                         female
# Last Author                                         unknown
# Second Author                                          male
# Penultimate Author                                     male
# Other Authors         [female, male, male, female, unknown]
# Name: 26255944, dtype: object
# <Article PMID: 26251854>
# Date                  2015-08-06
# Journal                     None
# First Author             unknown
# Last Author                 male
# Second Author            unknown
# Penultimate Author       unknown
# Other Authors           [female]
# Name: 26251854, dtype: object
# <Article PMID: 26021057>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-0dce5df48bfd> in <module>()
# ----> 1 make_csv_from_xml('comp-bio-1997-2014.xml', 'compbio_pubs2.csv')
#
# <ipython-input-22-c76aa0ef7374> in make_csv_from_xml(xml_file, name)
#      21       print(article)
#      22       first, last, second, penultimate, others = score_authors(article.authors)
# ---> 23       fa = get_gender(first.first_name)
#      24
#      25       if last:
#
# AttributeError: 'NoneType' object has no attribute 'first_name'

# %%
# make_csv_from_xml('biology-1997-2014.xml', 'all_bio_pubs.csv')
